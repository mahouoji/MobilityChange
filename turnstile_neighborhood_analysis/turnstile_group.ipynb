# %%
import pandas as pd
import numpy as np
from datetime import datetime
import os
import csv

# %%
is_exists = os.path.exists("../data/turnstile/station_rideship")
is_exists_2 = os.path.exists("../data/turnstile/date_rideship")

if not is_exists:
        os.makedirs("../data/turnstile/station_rideship")
        print ("Create stations dir")

if not is_exists_2:
        os.makedirs("../data/turnstile/date_rideship")
        print ("Create date dir")
# Out:
# Create stations dir
# Create date dir

# %%
data_path = '../data/turnstile'
turnstile_path = os.path.join(data_path, 'raw')
station_dir = os.path.join(data_path, 'station_rideship')
date_sum = os.path.join(data_path, 'date_rideship')

# %%
def flush_stations(stations):
    for station_name, rows in stations.items():
        
        name = ''.join(chars for chars in station_name if chars.isalnum())
        file_path = os.path.join(station_dir, name)
        file_path = file_path + '.csv'
        
        with open(file_path, mode = 'a+') as f:
            
            ff = csv.writer(f)
            ff.writerows(rows)

# %%
for file_name in os.listdir(turnstile_path):
    
    file_path = os.path.join(turnstile_path, file_name)
    stations = {}
    
    with open(file_path) as f:
        
        reader = csv.DictReader(f)
        
        for row in reader:
            if not row['DESC'] in ['RECOVER AUD', 'REGULAR']:
                continue
            
            res = [
                row['STATION'],
                row['DIVISION'] + row['UNIT'] + row['SCP'],
                row['DATE'],
                row['TIME'],
                row['ENTRIES']
            ]
            
            if not row['STATION'] in stations:
                stations[row['STATION']] = [res]
            else:
                stations[row['STATION']] += [res]
    
    flush_stations(stations)
    
print("Station Sum Complete !")
# Out:
# Station Sum Complete !

# %%
def cal_rideship(df):
    
    df_cal = df.resample('H').max().interpolate().ffill()
    df_cal['rideship'] = df_cal['entries'] - df_cal['entries'].shift(1)
    
    df_cal.loc[df_cal['rideship'] < 0, 'rideship'] = np.nan
    df_cal.loc[df_cal['rideship'] > 10000, 'rideship'] = np.nan
    
    res = df_cal.interpolate().dropna()
    
    return res

# %%
for file_name in os.listdir(station_dir):
    
    col_names = ['station', 'distinction', 'date', 'time', 'entries']
    data = pd.read_csv(os.path.join(station_dir, file_name), names = col_names)
    
    data['date_time'] = pd.to_datetime(data['date']+ ' ' +data['time'], format = '%m/%d/%Y %H:%M:%S')
    data.drop(columns = ['date', 'time'], inplace = True)
    data.set_index('date_time', inplace = True)
    
    rideship = data.groupby(['station', 'distinction'], group_keys=False).apply(cal_rideship)
    hour_rideship = rideship.groupby(['station', 'date_time'])['rideship'].sum().reset_index()
    date_rideship = hour_rideship.groupby(['station', pd.Grouper(key = 'date_time', freq = 'D')]).sum().reset_index()
    date_rideship.to_csv(os.path.join(date_sum, file_name), index = False, header = False)

    print('Processed %s'  % file_name)

print("Preprocess Complete !!")
# Out:
# Processed 103ST.csv
# Processed 103STCORONA.csv
# Processed 104ST.csv
# Processed 110ST.csv
# Processed 111ST.csv
# Processed 116ST.csv
# Processed 116STCOLUMBIA.csv
# Processed 121ST.csv
# Processed 125ST.csv
# Processed 135ST.csv
# Processed 137STCITYCOL.csv
# Processed 138GRANDCONC.csv
# Processed 145ST.csv
# Processed 149GRANDCONC.csv
# Processed 14ST.csv
# Processed 14STUNIONSQ.csv
# Processed 14THSTREET.csv
# Processed 155ST.csv
# Processed 157ST.csv
# Processed 15STPROSPECT.csv
# Processed 161YANKEESTAD.csv
# Processed 163STAMSTERDM.csv
# Processed 167ST.csv
# Processed 168ST.csv
# Processed 169ST.csv
# Processed 170ST.csv
# Processed 174175STS.csv
# Processed 174ST.csv
# Processed 175ST.csv
# Processed 176ST.csv
# Processed 181ST.csv
# Processed 182183STS.csv
# Processed 183ST.csv
# Processed 18AV.csv
# Processed 18ST.csv
# Processed 190ST.csv
# Processed 191ST.csv
# Processed 1AV.csv
# Processed 207ST.csv
# Processed 20AV.csv
# Processed 215ST.csv
# Processed 219ST.csv
# Processed 21ST.csv
# Processed 21STQNSBRIDGE.csv
# Processed 225ST.csv
# Processed 231ST.csv
# Processed 233ST.csv
# Processed 238ST.csv
# Processed 23ST.csv
# Processed 25AV.csv
# Processed 25ST.csv
# Processed 28ST.csv
# Processed 2AV.csv
# Processed 30AV.csv
# Processed 33ST.csv
# Processed 33STRAWSONST.csv
# Processed 34STHERALDSQ.csv
# Processed 34STHUDSONYD.csv
# Processed 34STPENNSTA.csv
# Processed 36AV.csv
# Processed 36ST.csv
# Processed 39AV.csv
# Processed 3AV.csv
# Processed 3AV138ST.csv
# Processed 3AV149ST.csv
# Processed 40STLOWERYST.csv
# Processed 42STBRYANTPK.csv
# Processed 42STPORTAUTH.csv
# Processed 45ST.csv
# Processed 46ST.csv
# Processed 46STBLISSST.csv
# Processed 4750STSROCK.csv
# Processed 49ST.csv
# Processed 4AV9ST.csv
# Processed 50ST.csv
# Processed 51ST.csv
# Processed 52ST.csv
# Processed 53ST.csv
# Processed 55ST.csv
# Processed 57ST.csv
# Processed 57ST7AV.csv
# Processed 59ST.csv
# Processed 59STCOLUMBUS.csv
# Processed 5AV53ST.csv
# Processed 5AV59ST.csv
# Processed 5AVE.csv
# Processed 61STWOODSIDE.csv
# Processed 63DRREGOPARK.csv
# Processed 65ST.csv
# Processed 66STLINCOLN.csv
# Processed 67AV.csv
# Processed 68STHUNTERCO.csv
# Processed 69ST.csv
# Processed 6AV.csv
# Processed 71ST.csv
# Processed 72ST.csv
# Processed 72ST2AVE.csv
# Processed 74STBROADWAY.csv
# Processed 75AV.csv
# Processed 75STELDERTS.csv
# Processed 77ST.csv
# Processed 79ST.csv
# Processed 7AV.csv
# Processed 80ST.csv
# Processed 81STMUSEUM.csv
# Processed 82STJACKSONH.csv
# Processed 85STFORESTPK.csv
# Processed 86ST.csv
# Processed 86ST2AVE.csv
# Processed 88ST.csv
# Processed 8AV.csv
# Processed 8STNYU.csv
# Processed 90STELMHURST.csv
# Processed 96ST.csv
# Processed 96ST2AVE.csv
# Processed 9AV.csv
# Processed 9THSTREET.csv
# Processed ALABAMAAV.csv
# Processed ALLERTONAV.csv
# Processed AQUEDUCTNCOND.csv
# Processed AQUEDUCTRACETR.csv
# Processed ASTORIABLVD.csv
# Processed ASTORIADITMARS.csv
# Processed ASTORPL.csv
# Processed ATLANTICAV.csv
# Processed ATLAVBARCLAY.csv
# Processed AVENUEH.csv
# Processed AVENUEI.csv
# Processed AVENUEJ.csv
# Processed AVENUEM.csv
# Processed AVENUEN.csv
# Processed AVENUEP.csv
# Processed AVENUEU.csv
# Processed AVENUEX.csv
# Processed BAY50ST.csv
# Processed BAYCHESTERAV.csv
# Processed BAYPKWY.csv
# Processed BAYRIDGE95ST.csv
# Processed BAYRIDGEAV.csv
# Processed BEACH105ST.csv
# Processed BEACH25ST.csv
# Processed BEACH36ST.csv
# Processed BEACH44ST.csv
# Processed BEACH60ST.csv
# Processed BEACH67ST.csv
# Processed BEACH90ST.csv
# Processed BEACH98ST.csv
# Processed BEDFORDAV.csv
# Processed BEDFORDNOSTRAN.csv
# Processed BEDFORDPKBLVD.csv
# Processed BERGENST.csv
# Processed BEVERLEYROAD.csv
# Processed BEVERLYRD.csv
# Processed BLEECKERST.csv
# Processed BOROUGHHALL.csv
# Processed BOTANICGARDEN.csv
# Processed BOWERY.csv
# Processed BOWLINGGREEN.csv
# Processed BRIARWOOD.csv
# Processed BRIGHTONBEACH.csv
# Processed BROADCHANNEL.csv
# Processed BROADST.csv
# Processed BROADWAY.csv
# Processed BROADWAYJCT.csv
# Processed BRONXPARKEAST.csv
# Processed BROOKAV.csv
# Processed BROOKLYNBRIDGE.csv
# Processed BUHREAV.csv
# Processed BURKEAV.csv
# Processed BURNSIDEAV.csv
# Processed BUSHWICKAV.csv
# Processed BWAYLAFAYETTE.csv
# Processed CANALST.csv
# Processed CANARSIEROCKAW.csv
# Processed CARROLLST.csv
# Processed CASTLEHILLAV.csv
# Processed CATHEDRALPKWY.csv
# Processed CENTRALAV.csv
# Processed CENTRALPKN110.csv
# Processed CHAMBERSST.csv
# Processed CHAUNCEYST.csv
# Processed CHRISTOPHERST.csv
# Processed CHURCHAV.csv
# Processed CITYBUS.csv
# Processed CITYHALL.csv
# Processed CLARKST.csv
# Processed CLASSONAV.csv
# Processed CLEVELANDST.csv
# Processed CLINTONWASHAV.csv
# Processed CONEYISSTILLW.csv
# Processed CORTELYOURD.csv
# Processed CORTLANDTST.csv
# Processed COURTSQ.csv
# Processed COURTSQ23ST.csv
# Processed CRESCENTST.csv
# Processed CROWNHTSUTICA.csv
# Processed CYPRESSAV.csv
# Processed CYPRESSHILLS.csv
# Processed DEKALBAV.csv
# Processed DELANCEYESSEX.csv
# Processed DITMASAV.csv
# Processed DYCKMANST.csv
# Processed E143STMARYS.csv
# Processed E149ST.csv
# Processed E180ST.csv
# Processed EAST105ST.csv
# Processed EASTBROADWAY.csv
# Processed EASTCHSTERDYRE.csv
# Processed EASTNPKWYMUSM.csv
# Processed ELDERAV.csv
# Processed ELMHURSTAV.csv
# Processed EUCLIDAV.csv
# Processed EXCHANGEPLACE.csv
# Processed FARROCKAWAY.csv
# Processed FLATBUSHAVBC.csv
# Processed FLUSHINGAV.csv
# Processed FLUSHINGMAIN.csv
# Processed FORDHAMRD.csv
# Processed FORESTAVE.csv
# Processed FORESTHILLS71.csv
# Processed FRANKLINAV.csv
# Processed FRANKLINST.csv
# Processed FREEMANST.csv
# Processed FRESHPONDRD.csv
# Processed FTHAMILTONPKY.csv
# Processed FULTONST.csv
# Processed GATESAV.csv
# Processed GRAHAMAV.csv
# Processed GRANDARMYPLAZ.csv
# Processed GRANDNEWTOWN.csv
# Processed GRANDST.csv
# Processed GRANTAV.csv
# Processed GRDCNTRL42ST.csv
# Processed GREENPOINTAV.csv
# Processed GROVESTREET.csv
# Processed GUNHILLRD.csv
# Processed HALSEYST.csv
# Processed HARLEM148ST.csv
# Processed HARRISON.csv
# Processed HEWESST.csv
# Processed HIGHST.csv
# Processed HOUSTONST.csv
# Processed HOWARDBCHJFK.csv
# Processed HOYTSCHER.csv
# Processed HOYTST.csv
# Processed HUNTERSPTAV.csv
# Processed HUNTSPOINTAV.csv
# Processed INTERVALEAV.csv
# Processed INWOOD207ST.csv
# Processed JACKSONAV.csv
# Processed JAMAICA179ST.csv
# Processed JAMAICACENTER.csv
# Processed JAMAICAVANWK.csv
# Processed JAYSTMETROTEC.csv
# Processed JEFFERSONST.csv
# Processed JFKJAMAICACT1.csv
# Processed JKSNHTROOSVLT.csv
# Processed JOURNALSQUARE.csv
# Processed JUNCTIONBLVD.csv
# Processed JUNIUSST.csv
# Processed KEWGARDENS.csv
# Processed KINGSBRIDGERD.csv
# Processed KINGSHWY.csv
# Processed KINGSTONAV.csv
# Processed KINGSTONTHROOP.csv
# Processed KNICKERBOCKER.csv
# Processed KOSCIUSZKOST.csv
# Processed LACKAWANNA.csv
# Processed LAFAYETTEAV.csv
# Processed LEXINGTONAV53.csv
# Processed LEXINGTONAV63.csv
# Processed LIBERTYAV.csv
# Processed LIVONIAAV.csv
# Processed LONGWOODAV.csv
# Processed LORIMERST.csv
# Processed MARBLEHILL225.csv
# Processed MARCYAV.csv
# Processed METROPOLITANAV.csv
# Processed METSWILLETSPT.csv
# Processed MIDDLETOWNRD.csv
# Processed MONTROSEAV.csv
# Processed MORGANAV.csv
# Processed MORISNAVSNDVW.csv
# Processed MORRISPARK.csv
# Processed MOSHOLUPKWY.csv
# Processed MTEDENAV.csv
# Processed MYRTLEAV.csv
# Processed MYRTLEWILLOUGH.csv
# Processed MYRTLEWYCKOFF.csv
# Processed NASSAUAV.csv
# Processed NECKRD.csv
# Processed NEPTUNEAV.csv
# Processed NEREIDAV.csv
# Processed NEVINSST.csv
# Processed NEWARKBMBW.csv
# Processed NEWARKC.csv
# Processed NEWARKHMHE.csv
# Processed NEWARKHWBMEBE.csv
# Processed NEWKIRKAV.csv
# Processed NEWKIRKPLAZA.csv
# Processed NEWLOTS.csv
# Processed NEWLOTSAV.csv
# Processed NEWUTRECHTAV.csv
# Processed NORTHERNBLVD.csv
# Processed NORWOOD205ST.csv
# Processed NORWOODAV.csv
# Processed NOSTRANDAV.csv
# Processed OCEANPKWY.csv
# Processed OZONEPKLEFFRT.csv
# Processed PARKCHESTER.csv
# Processed PARKPLACE.csv
# Processed PARKSIDEAV.csv
# Processed PARSONSBLVD.csv
# Processed PATHNEWWTC.csv
# Processed PATHWTC2.csv
# Processed PAVONIANEWPORT.csv
# Processed PELHAMBAYPARK.csv
# Processed PELHAMPKWY.csv
# Processed PENNSYLVANIAAV.csv
# Processed PRESIDENTST.csv
# Processed PRINCEST.csv
# Processed PROSPECTAV.csv
# Processed PROSPECTPARK.csv
# Processed QUEENSBOROPLZ.csv
# Processed QUEENSPLAZA.csv
# Processed RALPHAV.csv
# Processed RECTORST.csv
# Processed RITMANHATTAN.csv
# Processed RITROOSEVELT.csv
# Processed ROCKAWAYAV.csv
# Processed ROCKAWAYBLVD.csv
# Processed ROCKAWAYPARKB.csv
# Processed ROOSEVELTISLND.csv
# Processed SARATOGAAV.csv
# Processed SENECAAVE.csv
# Processed SHEEPSHEADBAY.csv
# Processed SHEPHERDAV.csv
# Processed SIMPSONST.csv
# Processed SMITH9ST.csv
# Processed SOUTHFERRY.csv
# Processed SPRINGST.csv
# Processed STEINWAYST.csv
# Processed STERLINGST.csv
# Processed STGEORGE.csv
# Processed STLAWRENCEAV.csv
# Processed SUTPHINARCHER.csv
# Processed SUTPHINBLVD.csv
# Processed SUTTERAV.csv
# Processed SUTTERAVRUTLD.csv
# Processed THIRTYST.csv
# Processed THIRTYTHIRDST.csv
# Processed TIMESSQ42ST.csv
# Processed TOMPKINSVILLE.csv
# Processed TREMONTAV.csv
# Processed TWENTYTHIRDST.csv
# Processed UNIONST.csv
# Processed UTICAAV.csv
# Processed VANSICLENAV.csv
# Processed VANSICLENAVE.csv
# Processed VCORTLANDTPK.csv
# Processed VERNONJACKSON.csv
# Processed W4STWASHSQ.csv
# Processed W8STAQUARIUM.csv
# Processed WAKEFIELD241.csv
# Processed WALLST.csv
# Processed WESTCHESTERSQ.csv
# Processed WESTFARMSSQ.csv
# Processed WHITEHALLSFRY.csv
# Processed WHITLOCKAV.csv
# Processed WILSONAV.csv
# Processed WINTHROPST.csv
# Processed WOODHAVENBLVD.csv
# Processed WOODLAWN.csv
# Processed WORLDTRADECTR.csv
# Processed WTCCORTLANDT.csv
# Processed YORKST.csv
# Processed ZEREGAAV.csv
# Preprocess Complete !!
