# %%
import sys
print('Python version: ', sys.version)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# ## Position Data

# %%
# data from https://github.com/chriswhong/nycturnstiles/blob/master/geocoded.csv
geo_df = pd.read_csv('../data/turnstile/geocoded_ca_unit.csv').dropna()
geo_df
# Out:
#     remote unit control area         station lines division   latitude  \
# 0          R470         X002  ELTINGVILLE PK     Z      SRT  40.544600
# 1          R544        PTH02        HARRISON     1      PTH  40.738879
# 2          R165         S102   TOMPKINSVILLE     1      SRT  40.636948
# 3          R070         S101      ST. GEORGE     1      SRT  40.643738
# 4          R070        S101A      ST. GEORGE     1      SRT  40.643738
# ..          ...          ...             ...   ...      ...        ...
# 787        R319        N601A   LEXINGTON AVE     F      IND  40.764763
# 788        R246         C015    PROSPECT AVE     R      BMT  40.665438
# 789        R001         R101     SOUTH FERRY   1RW      IRT  40.702068
# 790        R305        R107D    CORTLANDT ST     1      IRT  40.710454
# 791        R305        R108A    CORTLANDT ST     1      IRT  40.710454
#
#      longitude
# 0   -74.164581
# 1   -74.155533
# 2   -74.074824
# 3   -74.073622
# 4   -74.073622
# ..         ...
# 787 -73.966291
# 788 -73.992856
# 789 -74.013664
# 790 -74.011324
# 791 -74.011324
#
# [774 rows x 7 columns]

# %%
# Build map 
station_loc_map = folium.Map(location=[40.738, -73.98],
    zoom_start=11, tiles='cartodbpositron')

# Plot coordinates using comprehension list
for index, row in geo_df.iterrows():
    folium.CircleMarker(location=[row['latitude'], row['longitude']],
    color='#0080bb', fill_color='#0080bb', radius=1).add_to(station_loc_map) 

# Display map in Jupyter
station_loc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Trip Data from trunstile_cleaning

# %%
count_df = pd.read_csv('../data/turnstile/station_daily_diffs.csv')
count_df
# Out:
#          C/A  UNIT        STATION LINENAME        DATE  ENTRIES_DIFF  \
# 0       A002  R051          59 ST  NQR456W  02/15/2020        6445.0
# 1       A002  R051          59 ST  NQR456W  02/16/2020        6122.0
# 2       A002  R051          59 ST  NQR456W  02/17/2020        9228.0
# 3       A002  R051          59 ST  NQR456W  02/18/2020       11858.0
# 4       A002  R051          59 ST  NQR456W  02/19/2020       12519.0
# ...      ...   ...            ...      ...         ...           ...
# 46913  TRAM2  R469  RIT-ROOSEVELT        R  04/13/2020         238.0
# 46914  TRAM2  R469  RIT-ROOSEVELT        R  04/14/2020         433.0
# 46915  TRAM2  R469  RIT-ROOSEVELT        R  04/15/2020         395.0
# 46916  TRAM2  R469  RIT-ROOSEVELT        R  04/16/2020         408.0
# 46917  TRAM2  R469  RIT-ROOSEVELT        R  04/17/2020         377.0
#
#        EXITS_DIFF
# 0          3259.0
# 1          3888.0
# 2          6073.0
# 3          7907.0
# 4          7999.0
# ...           ...
# 46913        65.0
# 46914        61.0
# 46915        71.0
# 46916        60.0
# 46917        40.0
#
# [46918 rows x 7 columns]

# %%
station_df = count_df[['C/A', 'UNIT', 'STATION', 'LINENAME']].drop_duplicates()
station_df
# Out:
#          C/A  UNIT        STATION LINENAME
# 0       A002  R051          59 ST  NQR456W
# 63      A006  R079     5 AV/59 ST     NQRW
# 126     A007  R079     5 AV/59 ST     NQRW
# 189     A010  R080     57 ST-7 AV     NQRW
# 252     A011  R080     57 ST-7 AV     NQRW
# ...      ...   ...            ...      ...
# 46605   S101  R070     ST. GEORGE        1
# 46668  S101A  R070     ST. GEORGE        1
# 46731   S102  R165  TOMPKINSVILLE        1
# 46792  TRAM1  R468  RIT-MANHATTAN        R
# 46855  TRAM2  R469  RIT-ROOSEVELT        R
#
# [747 rows x 4 columns]

# %% [markdown]
# ## Join

# %%
geostation_df = pd.merge(station_df, geo_df, how='outer',
    left_on=['C/A', 'UNIT'], right_on=['control area', 'remote unit'], suffixes=['_l', '_r'])
geostation_df
# Out:
#       C/A  UNIT     STATION LINENAME remote unit control area  \
# 0    A002  R051       59 ST  NQR456W        R051         A002
# 1    A006  R079  5 AV/59 ST     NQRW        R079         A006
# 2    A007  R079  5 AV/59 ST     NQRW        R079         A007
# 3    A010  R080  57 ST-7 AV     NQRW        R080         A010
# 4    A011  R080  57 ST-7 AV     NQRW        R080         A011
# ..    ...   ...         ...      ...         ...          ...
# 781   NaN   NaN         NaN      NaN        R328        R532G
# 782   NaN   NaN         NaN      NaN        R414        N182A
# 783   NaN   NaN         NaN      NaN        R459         OB01
# 784   NaN   NaN         NaN      NaN        R537        JFK04
# 785   NaN   NaN         NaN      NaN        R001        R101S
#
#              station   lines division   latitude  longitude
# 0      LEXINGTON AVE  456NQR      BMT  40.762796 -73.967686
# 1        5 AVE-59 ST     NQR      BMT  40.764909 -73.973372
# 2        5 AVE-59 ST     NQR      BMT  40.764909 -73.973372
# 3        57 ST-7 AVE     NQR      BMT  40.764755 -73.980646
# 4        57 ST-7 AVE     NQR      BMT  40.764755 -73.980646
# ..               ...     ...      ...        ...        ...
# 781  METS-WILLETS PT       7      IRT  40.754622 -73.845625
# 782   HOWARD BCH-JFK       A      IND  40.660476 -73.830301
# 783    ORCHARD BEACH       6      IND  40.852417 -73.828082
# 784  JFK JAMAICA CT2       E      IND  40.643942 -73.782356
# 785      SOUTH FERRY      R1      IRT  40.703082 -74.012983
#
# [786 rows x 11 columns]

# %% [markdown]
# ### Repairing some data

# %%
geostation_df[geostation_df.isna().any(axis=1)]
# Out:
#        C/A  UNIT          STATION LINENAME remote unit control area  \
# 438  PTH01  R549  NEWARK HW BMEBE        1         NaN          NaN
# 443  PTH06  R546  PAVONIA/NEWPORT        1         NaN          NaN
# 444  PTH07  R550       CITY / BUS        1         NaN          NaN
# 446  PTH10  R547       9TH STREET        1         NaN          NaN
# 449  PTH13  R541        THIRTY ST        1         NaN          NaN
# 450  PTH16  R550       LACKAWANNA        1         NaN          NaN
# 452  PTH18  R549     NEWARK BM BW        1         NaN          NaN
# 453  PTH19  R549         NEWARK C        1         NaN          NaN
# 454  PTH20  R549     NEWARK HM HE        1         NaN          NaN
# 456  PTH22  R540     PATH NEW WTC        1         NaN          NaN
# 699   R550  R072  34 ST-HUDSON YD        7         NaN          NaN
# 700   R551  R072  34 ST-HUDSON YD        7         NaN          NaN
# 747    NaN   NaN              NaN      NaN        R470         X002
# 748    NaN   NaN              NaN      NaN        R212         C021
# 749    NaN   NaN              NaN      NaN        R076        MCC07
# 750    NaN   NaN              NaN      NaN        R088         A051
# 751    NaN   NaN              NaN      NaN        R540        PTH08
# 752    NaN   NaN              NaN      NaN        R002         A077
# 753    NaN   NaN              NaN      NaN        R002         A081
# 754    NaN   NaN              NaN      NaN        R002         A082
# 755    NaN   NaN              NaN      NaN        R014         R205
# 756    NaN   NaN              NaN      NaN        R028        R113A
# 757    NaN   NaN              NaN      NaN        R462         A044
# 758    NaN   NaN              NaN      NaN        R463         R214
# 759    NaN   NaN              NaN      NaN        R012         N065
# 760    NaN   NaN              NaN      NaN        R454         C015
# 761    NaN   NaN              NaN      NaN        R170         A036
# 762    NaN   NaN              NaN      NaN        R032         R146
# 763    NaN   NaN              NaN      NaN        R033         R150
# 764    NaN   NaN              NaN      NaN        R033         R153
# 765    NaN   NaN              NaN      NaN        R054         R500
# 766    NaN   NaN              NaN      NaN        R248         H008
# 767    NaN   NaN              NaN      NaN        R288        N539A
# 768    NaN   NaN              NaN      NaN        R057         B001
# 769    NaN   NaN              NaN      NaN        R057         B002
# 770    NaN   NaN              NaN      NaN        R045         R233
# 771    NaN   NaN              NaN      NaN        R168         R168
# 772    NaN   NaN              NaN      NaN        R186         N042
# 773    NaN   NaN              NaN      NaN        R050         A004
# 774    NaN   NaN              NaN      NaN        R239         N403
# 775    NaN   NaN              NaN      NaN        R359         N400
# 776    NaN   NaN              NaN      NaN        R195         N204
# 777    NaN   NaN              NaN      NaN        R154         N214
# 778    NaN   NaN              NaN      NaN        R387        R323A
# 779    NaN   NaN              NaN      NaN        R538        LGA01
# 780    NaN   NaN              NaN      NaN        R202        N330B
# 781    NaN   NaN              NaN      NaN        R328        R532G
# 782    NaN   NaN              NaN      NaN        R414        N182A
# 783    NaN   NaN              NaN      NaN        R459         OB01
# 784    NaN   NaN              NaN      NaN        R537        JFK04
# 785    NaN   NaN              NaN      NaN        R001        R101S
#
#              station        lines division   latitude  longitude
# 438              NaN          NaN      NaN        NaN        NaN
# 443              NaN          NaN      NaN        NaN        NaN
# 444              NaN          NaN      NaN        NaN        NaN
# 446              NaN          NaN      NaN        NaN        NaN
# 449              NaN          NaN      NaN        NaN        NaN
# 450              NaN          NaN      NaN        NaN        NaN
# 452              NaN          NaN      NaN        NaN        NaN
# 453              NaN          NaN      NaN        NaN        NaN
# 454              NaN          NaN      NaN        NaN        NaN
# 456              NaN          NaN      NaN        NaN        NaN
# 699              NaN          NaN      NaN        NaN        NaN
# 700              NaN          NaN      NaN        NaN        NaN
# 747   ELTINGVILLE PK            Z      SRT  40.544600 -74.164581
# 748            59 ST           NR      BMT  40.641426 -74.017972
# 749  2 BDWY CUST SRV           45      IRT  40.704591 -74.013273
# 750     CORTLANDT ST            R      BMT  40.710662 -74.011052
# 751         PATH WTC            1      PTH  40.711638 -74.010708
# 752        FULTON ST     ACJZ2345      BMT  40.709938 -74.007983
# 753        FULTON ST     ACJZ2345      BMT  40.709938 -74.007983
# 754        FULTON ST     ACJZ2345      BMT  40.709938 -74.007983
# 755        FULTON ST     ACJZ2345      IRT  40.709938 -74.007983
# 756        FULTON ST     2345ACJZ      IRT  40.709938 -74.007983
# 757         CANAL ST       JNQRZ6      BMT  40.718697 -74.000977
# 758         CANAL ST       JNQRZ6      IRT  40.718697 -74.000977
# 759   34 ST-PENN STA          ACE      IND  40.752247 -73.993456
# 760     PROSPECT AVE            R      BMT  40.665405 -73.992877
# 761   14 ST-UNION SQ      LNQR456      BMT  40.734836 -73.990688
# 762   42 ST-TIMES SQ  1237ACENQRS      IRT  40.755905 -73.986504
# 763   42 ST-TIMES SQ  1237ACENQRS      IRT  40.755905 -73.986504
# 764   42 ST-TIMES SQ  1237ACENQRS      IRT  40.755905 -73.986504
# 765  5 AVE-BRYANT PK        7BDFM      IRT  40.753824 -73.981966
# 766            1 AVE            L      BMT  40.730901 -73.981719
# 767  7 AV-PARK SLOPE           FG      IND  40.666276 -73.980324
# 768     ATLANTIC AVE    2345BDNQR      BMT  40.684063 -73.977417
# 769     ATLANTIC AVE    BDNQR2345      BMT  40.684063 -73.977417
# 770  42 ST-GRD CNTRL        4567S      IRT  40.751849 -73.976945
# 771            96 ST          123      IRT  40.793880 -73.972363
# 772            86 ST           BC      IND  40.785822 -73.968952
# 773    LEXINGTON AVE       456NQR      BMT  40.762796 -73.967686
# 774   GREENPOINT AVE            G      IND  40.731324 -73.954425
# 775         COURT SQ          EMG      IND  40.747257 -73.945112
# 776    161 ST-YANKEE          BD4      IND  40.827888 -73.925736
# 777      TREMONT AVE           BD      IND  40.850307 -73.905244
# 778    E TREMONT AVE           25      IRT  40.840097 -73.879774
# 779  LGA AIRPORT CTB            7      IRT  40.774702 -73.871189
# 780  63 DR-REGO PARK           MR      IND  40.729869 -73.861610
# 781  METS-WILLETS PT            7      IRT  40.754622 -73.845625
# 782   HOWARD BCH-JFK            A      IND  40.660476 -73.830301
# 783    ORCHARD BEACH            6      IND  40.852417 -73.828082
# 784  JFK JAMAICA CT2            E      IND  40.643942 -73.782356
# 785      SOUTH FERRY           R1      IRT  40.703082 -74.012983

# %%
geostation_nona_df = geostation_df.dropna()
geostation_nona_df
# Out:
#        C/A  UNIT        STATION LINENAME remote unit control area  \
# 0     A002  R051          59 ST  NQR456W        R051         A002
# 1     A006  R079     5 AV/59 ST     NQRW        R079         A006
# 2     A007  R079     5 AV/59 ST     NQRW        R079         A007
# 3     A010  R080     57 ST-7 AV     NQRW        R080         A010
# 4     A011  R080     57 ST-7 AV     NQRW        R080         A011
# ..     ...   ...            ...      ...         ...          ...
# 742   S101  R070     ST. GEORGE        1        R070         S101
# 743  S101A  R070     ST. GEORGE        1        R070        S101A
# 744   S102  R165  TOMPKINSVILLE        1        R165         S102
# 745  TRAM1  R468  RIT-MANHATTAN        R        R468        TRAM1
# 746  TRAM2  R469  RIT-ROOSEVELT        R        R469        TRAM2
#
#            station   lines division   latitude  longitude
# 0    LEXINGTON AVE  456NQR      BMT  40.762796 -73.967686
# 1      5 AVE-59 ST     NQR      BMT  40.764909 -73.973372
# 2      5 AVE-59 ST     NQR      BMT  40.764909 -73.973372
# 3      57 ST-7 AVE     NQR      BMT  40.764755 -73.980646
# 4      57 ST-7 AVE     NQR      BMT  40.764755 -73.980646
# ..             ...     ...      ...        ...        ...
# 742     ST. GEORGE       1      SRT  40.643738 -74.073622
# 743     ST. GEORGE       1      SRT  40.643738 -74.073622
# 744  TOMPKINSVILLE       1      SRT  40.636948 -74.074824
# 745  RIT-MANHATTAN       R      RIT  40.761268 -73.964016
# 746  RIT-ROOSEVELT       R      RIT  40.757400 -73.954006
#
# [735 rows x 11 columns]

# %%
# Build map 
station_loc_map = folium.Map(location=[40.738, -73.98],
    zoom_start=11, tiles='cartodbpositron', width=640, height=480)

# Plot coordinates using comprehension list
for index, row in geostation_nona_df.iterrows():
    folium.CircleMarker(location=[row['latitude'], row['longitude']],
    color='#0080bb', fill_color='#0080bb', radius=1).add_to(station_loc_map) 

# Display map in Jupyter
station_loc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Station position not found

# %%
geo_not_found = geostation_df[geostation_df['control area'].isnull()][['C/A', 'UNIT', 'STATION', 'LINENAME']]
geo_not_found.sort_values('STATION')
# Out:
#        C/A  UNIT          STATION LINENAME
# 699   R550  R072  34 ST-HUDSON YD        7
# 700   R551  R072  34 ST-HUDSON YD        7
# 446  PTH10  R547       9TH STREET        1
# 444  PTH07  R550       CITY / BUS        1
# 450  PTH16  R550       LACKAWANNA        1
# 452  PTH18  R549     NEWARK BM BW        1
# 453  PTH19  R549         NEWARK C        1
# 454  PTH20  R549     NEWARK HM HE        1
# 438  PTH01  R549  NEWARK HW BMEBE        1
# 456  PTH22  R540     PATH NEW WTC        1
# 443  PTH06  R546  PAVONIA/NEWPORT        1
# 449  PTH13  R541        THIRTY ST        1

# %%
station_namae = '34 ST-HUDSON YD'
geo_not_found[geo_not_found['STATION'] == station_namae]
# Out:
#       C/A  UNIT          STATION LINENAME
# 699  R550  R072  34 ST-HUDSON YD        7
# 700  R551  R072  34 ST-HUDSON YD        7

# %%
geostation_nona_df[geostation_nona_df['STATION'] == station_namae]
# Out:
# Empty DataFrame
# Columns: [C/A, UNIT, STATION, LINENAME, remote unit, control area, station, lines, division, latitude, longitude]
# Index: []

# %%
station_df[station_df['STATION'] == station_namae]
# Out:
#         C/A  UNIT          STATION LINENAME
# 43897  R550  R072  34 ST-HUDSON YD        7
# 43960  R551  R072  34 ST-HUDSON YD        7

# %%
count_df[count_df['STATION'] == station_namae].sort_values('DATE')
# Out:
#         C/A  UNIT          STATION LINENAME        DATE  ENTRIES_DIFF  \
# 43897  R550  R072  34 ST-HUDSON YD        7  02/15/2020        9927.0
# 43960  R551  R072  34 ST-HUDSON YD        7  02/15/2020        1453.0
# 43898  R550  R072  34 ST-HUDSON YD        7  02/16/2020        8895.0
# 43961  R551  R072  34 ST-HUDSON YD        7  02/16/2020        1266.0
# 43899  R550  R072  34 ST-HUDSON YD        7  02/17/2020       11131.0
# ...     ...   ...              ...      ...         ...           ...
# 43957  R550  R072  34 ST-HUDSON YD        7  04/15/2020         642.0
# 44021  R551  R072  34 ST-HUDSON YD        7  04/16/2020         191.0
# 43958  R550  R072  34 ST-HUDSON YD        7  04/16/2020         654.0
# 43959  R550  R072  34 ST-HUDSON YD        7  04/17/2020         565.0
# 44022  R551  R072  34 ST-HUDSON YD        7  04/17/2020         173.0
#
#        EXITS_DIFF
# 43897     10785.0
# 43960      2262.0
# 43898      9532.0
# 43961      1976.0
# 43899     12177.0
# ...           ...
# 43957       716.0
# 44021       235.0
# 43958       746.0
# 43959       690.0
# 44022       232.0
#
# [126 rows x 7 columns]
